# %%
import pandas as pd
import numpy as np

# %%
url="https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/breast-cancer.csv"
df = pd.read_csv(url)
df.sample(10)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 49     857156         B        13.49         22.30           86.91      561.0
# 95      86208         M        20.26         23.03          132.40     1264.0
# 382     90250         B        12.05         22.72           78.75      447.8
# 207    879830         M        17.01         20.26          109.70      904.3
# 450   9111596         B        11.87         21.54           76.83      432.0
# 242    883852         B        11.30         18.19           73.93      389.4
# 255    886452         M        13.96         17.05           91.43      602.4
# 231  88199202         B        11.32         27.08           71.76      395.7
# 132  86730502         M        16.16         21.54          106.20      809.8
# 88     861597         B        12.36         21.80           79.78      466.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 49           0.08752           0.07698         0.04751             0.033840
# 95           0.09078           0.13130         0.14650             0.086830
# 382          0.06935           0.10730         0.07943             0.029780
# 207          0.08772           0.07304         0.06950             0.053900
# 450          0.06613           0.10640         0.08777             0.023860
# 242          0.09592           0.13250         0.15480             0.028540
# 255          0.10960           0.12790         0.09789             0.052460
# 231          0.06883           0.03813         0.01633             0.003125
# 132          0.10080           0.12840         0.10430             0.056130
# 88           0.08772           0.09445         0.06015             0.037450
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 49   ...         15.15          31.82            99.00       698.8
# 95   ...         24.22          31.59           156.10      1750.0
# 382  ...         12.57          28.71            87.36       488.4
# 207  ...         19.80          25.05           130.00      1210.0
# 450  ...         12.79          28.18            83.51       507.2
# 242  ...         12.58          27.96            87.16       472.9
# 255  ...         16.39          22.07           108.10       826.0
# 231  ...         12.08          33.75            79.82       452.3
# 132  ...         19.47          31.68           129.70      1175.0
# 88   ...         13.83          30.50            91.46       574.7
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 49            0.11620             0.1711           0.2282
# 95            0.11900             0.3539           0.4098
# 382           0.08799             0.3214           0.2912
# 207           0.11110             0.1486           0.1932
# 450           0.09457             0.3399           0.3218
# 242           0.13470             0.4848           0.7436
# 255           0.15120             0.3262           0.3209
# 231           0.09203             0.1432           0.1089
# 132           0.13950             0.3055           0.2992
# 88            0.13040             0.2463           0.2434
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 49                0.12820          0.2871                  0.06917
# 95                0.15730          0.3689                  0.08368
# 382               0.10920          0.2191                  0.09349
# 207               0.10960          0.3275                  0.06469
# 450               0.08750          0.2305                  0.09952
# 242               0.12180          0.3308                  0.12970
# 255               0.13740          0.3068                  0.07957
# 231               0.02083          0.2849                  0.07087
# 132               0.13120          0.3480                  0.07619
# 88                0.12050          0.2972                  0.09261
#
# [10 rows x 32 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
df['diagnosis'] = labelEncoder.fit_transform(df['diagnosis'].values)
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
df.drop(columns=['id'], inplace=True)

# %%
df.head(1)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38           122.8     1001.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1184            0.2776          0.3001               0.1471
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33            184.6
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                   0.1189
#
# [1 rows x 31 columns]

# %%
corr_metrics = df.corr().abs()
corr_metrics.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T
{
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_82670_row1_col17, #T_82670_row12_col16, #T_82670_row12_col17, #T_82670_row14_col12, #T_82670_row19_col23, #T_82670_row21_col12, #T_82670_row24_col19 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_82670_row1_col19, #T_82670_row12_col23, #T_82670_row15_col30, #T_82670_row19_col1, #T_82670_row23_col19, #T_82670_row24_col17, #T_82670_row25_col16, #T_82670_row29_col2, #T_82670_row29_col15 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_82670_row1_col20, #T_82670_row12_col30, #T_82670_row13_col10, #T_82670_row20_col29 {
#   background-color

# %%
df.corrwith(df['diagnosis']).abs().sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# concave points_worst       0.793566
# perimeter_worst            0.782914
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# radius_mean                0.730029
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.596534
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.548236
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# fractal_dimension_se       0.077972
# smoothness_se              0.067016
# fractal_dimension_mean     0.012838
# texture_se                 0.008303
# symmetry_se                0.006522
# dtype: float64

# %%
X = df.drop(columns=['diagnosis'], axis=1).values
Y = df['diagnosis']

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
X
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
from sklearn.preprocessing import StandardScaler
standart = StandardScaler()
X = standart.fit_transform(X)

# %%
X
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(X,Y, test_size=0.2, random_state=30)

# %%
len(x_train)
# Out:
# 455

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(x_test)

# %%
y_test.head(10)
# Out:
# 197    1
# 351    1
# 338    0
# 47     1
# 474    0
# 24     1
# 309    0
# 556    0
# 158    0
# 364    0
# Name: diagnosis, dtype: int64

# %%
from sklearn.metrics import jaccard_score
jaccard_score(y_test, y_predict)
# Out:
# 0.8888888888888888

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_predict)
# Out:
# array([[69,  1],
#        [ 4, 40]])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(confusion_matrix(y_test, y_predict), annot=True)
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97        70
#            1       0.98      0.91      0.94        44
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
