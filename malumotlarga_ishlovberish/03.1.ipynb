# %%
! git clone  https://github.com/anvarnarz/praktikum_datasets.git
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # # Dropna() va fillna() methodlari
#
# *   Новый пункт
# *   Новый пункт

# %%
df = pd.read_csv("praktikum_datasets/automobile_data_nan.csv")

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         NaN             21.0  13495.0
# 1             four       111.0             21.0  16500.0
# 2              six       154.0              NaN  16500.0
# 3             four       102.0             24.0  13950.0
# 4             five         NaN              NaN  17450.0

# %%
df.isnull() # agar qiymat bo'lmas true qaytaradi
# Out:
#     index  company  body-style  wheel-base  length  engine-type  \
# 0   False    False       False       False   False        False
# 1   False    False       False        True   False        False
# 2   False    False       False       False   False        False
# 3   False    False       False       False   False        False
# 4   False    False       False       False   False        False
# ..    ...      ...         ...         ...     ...          ...
# 56  False    False       False       False   False        False
# 57  False    False       False        True   False         True
# 58  False    False       False       False    True        False
# 59  False    False       False       False   False         True
# 60  False    False       False       False   False        False
#
#     num-of-cylinders  horsepower  average-mileage  price
# 0              False        True            False  False
# 1              False       False            False  False
# ...

# %%
#df.notnull()
df.isnull().sum() # yoq qiymatlarni sonini hisoblaydi
# Out:
# index                0
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %%
len(df)
# Out:
# 61

# %%
df.isnull().sum()/len(df)*100 # bu qiymatlarni foizda chiqarib berad i
# Out:
# index                0.000000
# company              0.000000
# body-style           0.000000
# wheel-base          24.590164
# length              21.311475
# engine-type         19.672131
# num-of-cylinders     0.000000
# horsepower          26.229508
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %%
df.dropna().head() # nan bo'lgan qiymatlarni tashlab yuboradi
# Out:
#     index    company body-style  wheel-base  length engine-type  \
# 3       3       audi      sedan        99.8   176.6         ohc
# 5       5       audi      sedan        99.8   177.3         ohc
# 6       6       audi      wagon       105.8   192.7         ohc
# 14     17  chevrolet  hatchback        94.5   155.9         ohc
# 16     19      dodge  hatchback        93.7   157.3         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 3              four       102.0             24.0  13950.0
# 5              five       110.0             19.0  15250.0
# 6              five       110.0             19.0  18920.0
# 14             four        70.0             38.0   6295.0
# 16             four        68.0             31.0   6377.0

# %%
len(df.dropna())
# Out:
# 14

# %%
df = df.dropna(axis=1) # columns larni nan qiymatlarni tashlab yuboradi

# %%
len(df.dropna(axis=1))
# Out:
# 61

# %%
df.dropna(axis=1, thresh=48) # thresh funksiyasi bu shart qoyadi 48 dan kam bo'lmasin deb
# Out:
#     index      company   body-style num-of-cylinders
# 0       0  alfa-romero  convertible             four
# 1       1  alfa-romero  convertible             four
# 2       2  alfa-romero    hatchback              six
# 3       3         audi        sedan             four
# 4       4         audi        sedan             five
# ..    ...          ...          ...              ...
# 56     81   volkswagen        sedan             four
# 57     82   volkswagen        sedan             four
# 58     86   volkswagen        sedan             four
# 59     87        volvo        sedan             four
# 60     88        volvo        wagon             four
#
# [61 rows x 4 columns]

# %%
df.dropna(subset=['horsepower','price']) # agar biz dropna ichida inplace komandasi ishlatsak bu df ni o'ziga o'zgarishlarni saqlaydi
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 1       1    alfa-romero  convertible         NaN   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 8      10            bmw        sedan         NaN   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 11     14            bmw        sedan       103.5     NaN         ohc
# 12     15            bmw        sedan       110.0   197.0         ohc
# 14     17      chevrolet    hatchback        94.5   155.9         ohc
# 15     18      chevrolet        sedan         NaN   158.8         ohc
# 16     19          dodge    hatchback        93.7   157.3         ohc
# ...

# %%
df.shape # shape matritsani hisoblaydi
# Out:
# (61, 10)

# %%
df.fillna(0) # bu barcha mavjud bo'lmagan qiymatlar o'rniga 0 qiymat qoyadi 
# biz 0 o'rniga xohlsagan raqamni qoyamiz
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         0.0   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         0.0   171.7           0
# 58     86   volkswagen        sedan        97.3     0.0         ohc
# 59     87        volvo        sedan       104.3   188.8           0
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         0.0             21.0  13495.0
# ...

# %%
df.fillna({'horsepower':99,'average-mileage':101})
# BU bizga ikkita columns yoq qiymatlarni 99, 101 qaytaradi
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four        99.0             21.0  13495.0
# ...

# %%
df.fillna({'horsepower':99,'average-mileage':101})
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four        99.0             21.0  13495.0
# ...

# %%
df.fillna({'horsepower':np.mean(df['horsepower']),'wheel-base':np.mean(df['wheel-base']) }) # bu yoq qiymatlarda aniq qiymat berish
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible   88.600000   168.8        dohc
# 1       1  alfa-romero  convertible   99.219565   168.8        dohc
# 2       2  alfa-romero    hatchback   94.500000   171.2        ohcv
# 3       3         audi        sedan   99.800000   176.6         ohc
# 4       4         audi        sedan   99.400000   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan   97.300000   171.7         ohc
# 57     82   volkswagen        sedan   99.219565   171.7         NaN
# 58     86   volkswagen        sedan   97.300000     NaN         ohc
# 59     87        volvo        sedan  104.300000   188.8         NaN
# 60     88        volvo        wagon  104.300000   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four  108.266667             21.0  13495.0
# ...

# %%
np.mean(df['wheel-base']) # bu qatordagi o'rta qiymatni hisoblaydi
# Out:
# 99.2195652173913

# %%
df.fillna(method='ffill') # bu oldingi qatorga nisbatan to'ldiradi
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         NaN             21.0  13495.0
# ...

# %%
df.fillna(method='bfill') # bu keyingi qatorga qarab to'ldrib ketadi
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        94.5   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   188.8         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four       111.0             21.0  13495.0
# ...

# %%
df[df.company=='toyota'].fillna(method='bfill') # bunda qiymatlarni filterlab oldidagi qiymat oladi
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48        62.0             35.0   5348.0
# 49        62.0             31.0   6338.0
# 50        62.0             31.0   6488.0
# 51        62.0             31.0   6918.0
# 52        62.0             27.0   7898.0
# 53       156.0             27.0   8778.0
# 54       156.0              NaN  15750.0

# %%
df[df.company=='toyota'] = df[df.company=='toyota'].fillna(method='bfill')

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         NaN             21.0  13495.0
# ...

# %%
df[df.company=='toyota']
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48        62.0             35.0   5348.0
# 49        62.0             31.0   6338.0
# 50        62.0             31.0   6488.0
# 51        62.0             31.0   6918.0
# 52        62.0             27.0   7898.0
# 53       156.0             27.0   8778.0
# 54       156.0              NaN  15750.0

# %%
df.fillna(df.mean()) # bu o'rtacha qiymatni hisoblab bo'sh qiymatlarga qoyadi
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#     index      company   body-style  wheel-base      length engine-type  \
# 0       0  alfa-romero  convertible   88.600000  168.800000        dohc
# 1       1  alfa-romero  convertible   99.072917  168.800000        dohc
# 2       2  alfa-romero    hatchback   94.500000  171.200000        ohcv
# 3       3         audi        sedan   99.800000  176.600000         ohc
# 4       4         audi        sedan   99.400000  176.600000         ohc
# ..    ...          ...          ...         ...         ...         ...
# 56     81   volkswagen        sedan   97.300000  171.700000         ohc
# ...

# %%
df1 = df[df['body-style']=='hatchback']

# %%
df1
# Out:
#     index      company body-style  wheel-base  length engine-type  \
# 2       2  alfa-romero  hatchback        94.5   171.2        ohcv
# 13     16    chevrolet  hatchback        88.4   141.1           l
# 14     17    chevrolet  hatchback        94.5   155.9         ohc
# 16     19        dodge  hatchback        93.7   157.3         ohc
# 17     20        dodge  hatchback        93.7     NaN         ohc
# 27     36        mazda  hatchback        93.1   159.1         NaN
# 28     37        mazda  hatchback        93.1   159.1         ohc
# 29     38        mazda  hatchback        93.1   159.1         ohc
# 30     39        mazda  hatchback         NaN     NaN         NaN
# 36     49   mitsubishi  hatchback         NaN   157.3         ohc
# 37     50   mitsubishi  hatchback        93.7     NaN         NaN
# 47     63      porsche  hatchback        98.4   175.7       dohcv
# 48     66       toyota  hatchback        95.7   158.7         ohc
# ...

# %%
df1['wheel-base'].mean()
# Out:
# 94.10000000000001

# %%
df.fillna({'wheel-base':df1['wheel-base'].mean()}, inplace=True)

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        94.1   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        94.1   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         NaN             21.0  13495.0
# ...

# %%
df.isnull().sum()/len(df)*100
# Out:
# index                0.000000
# company              0.000000
# body-style           0.000000
# wheel-base           0.000000
# length              19.672131
# engine-type         16.393443
# num-of-cylinders     0.000000
# horsepower          22.950820
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %% [markdown]
# # Takroriy qiymatlarni o'chirish

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets.git
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('praktikum_datasets/world_population_duplicates.csv')

# %%
df
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 3       1             Macau  21946.4667  56841.3487    658.394       30
# 4       2            Monaco  19755.5000  51166.7450     39.511        2
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [247 rows x 6 columns]

# %%
df.head()
# Out:
#    rank  country     density   densityMi    pop2021   area
# 0     1    Macau  21946.4667  56841.3487    658.394     30
# 1     2   Monaco  19755.5000  51166.7450     39.511      2
# 2    28  Burundi    440.3044   1140.3884  12255.433  27834
# 3     1    Macau  21946.4667  56841.3487    658.394     30
# 4     2   Monaco  19755.5000  51166.7450     39.511      2

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# Length: 247, dtype: bool

# %%
df.shape
# Out:
# (247, 6)

# %%
df.duplicated().sum()
# Out:
# 15

# %%
df.drop_duplicates( inplace=True)

# %%
df.shape
# Out:
# (232, 6)

# %%
df.drop_duplicates( ['country'],inplace=True)

# %%
df
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %% [markdown]
# # .map() Qiymatlarni moslash va almashtirish
# ## Dataframe larda ma'lumotlarda ishlov berish asosan map() va apply() funksiyalari yordamida malga oshiradi

# %%
df=  pd.read_csv('praktikum_datasets/automobile_data_nan.csv')

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         NaN             21.0  13495.0
# 1             four       111.0             21.0  16500.0
# 2              six       154.0              NaN  16500.0
# 3             four       102.0             24.0  13950.0
# 4             five         NaN              NaN  17450.0

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
dict = {'four':4, 'six':6, 'five':5, 'three':3, 'twelve':12, 'two':2, 'eight':8}

# %%
df['clinder'] = df['num-of-cylinders'].map(dict) # map() funksiyasi funksiya ham ro'yhat ham qabul qilai

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price  clinder
# 0             four         NaN             21.0  13495.0        4
# 1             four       111.0             21.0  16500.0        4
# 2              six       154.0              NaN  16500.0        6
# 3             four       102.0             24.0  13950.0        4
# 4             five         NaN              NaN  17450.0        5

# %%
df.price
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %%
kurs = 10720
df["uzsum"] = df['price'].map(lambda x: x*10720) # bu yerda ma() funksiyasi fuknsiya qabul qilib olyapti

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price  clinder        uzsum
# 0             four         NaN             21.0  13495.0        4  144666400.0
# 1             four       111.0             21.0  16500.0        4  176880000.0
# 2              six       154.0              NaN  16500.0        6  176880000.0
# 3             four       102.0             24.0  13950.0        4  149544000.0
# 4             five         NaN              NaN  17450.0        5  187064000.0

# %% [markdown]
# # .replace() va .rename() qiymatlarni o'zgartirish

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price  clinder  \
# 0              four         NaN             21.0  13495.0        4
# ...

# %%
df.replace('four', 4) # bu funksiya four degan qiymatni 4 o'zgartiradi
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price  clinder  \
# 0                 4         NaN             21.0  13495.0        4
# ...

# %%
dict = {'four':4, 'six':6, 'five':5, 'three':3, 'twelve':12, 'two':2, 'eight':8}
df.replace(dict) # agar bir nechta qiymatlarni bersak
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#     num-of-cylinders  horsepower  average-mileage    price  clinder  \
# 0                  4         NaN             21.0  13495.0        4
# ...

# %%
df2=pd.read_csv('world_population_duplicates.csv')

# %%
df2.head()
# Out:
#    rank  country     density   densityMi    pop2021   area
# 0     1    Macau  21946.4667  56841.3487    658.394     30
# 1     2   Monaco  19755.5000  51166.7450     39.511      2
# 2    28  Burundi    440.3044   1140.3884  12255.433  27834
# 3     1    Macau  21946.4667  56841.3487    658.394     30
# 4     2   Monaco  19755.5000  51166.7450     39.511      2

# %%
df2.rename(columns=str.upper) # columns larni katta harf bilan yozadi
# Out:
#      RANK           COUNTRY     DENSITY   DENSITYMI    POP2021     AREA
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 3       1             Macau  21946.4667  56841.3487    658.394       30
# 4       2            Monaco  19755.5000  51166.7450     39.511        2
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [247 rows x 6 columns]

# %%
df2.rename(columns=str.title)
# Out:
#      Rank           Country     Density   Densitymi    Pop2021     Area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 3       1             Macau  21946.4667  56841.3487    658.394       30
# 4       2            Monaco  19755.5000  51166.7450     39.511        2
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [247 rows x 6 columns]

# %%
df2.head()
# Out:
#    rank  country     density   densityMi    pop2021   area
# 0     1    Macau  21946.4667  56841.3487    658.394     30
# 1     2   Monaco  19755.5000  51166.7450     39.511      2
# 2    28  Burundi    440.3044   1140.3884  12255.433  27834
# 3     1    Macau  21946.4667  56841.3487    658.394     30
# 4     2   Monaco  19755.5000  51166.7450     39.511      2

# %%
df2.rename(columns={'pop2021':'population'},inplace=True) # biz ustun nomini ham o'zgartirishimiz munkin

# %%
df2.head()
# Out:
#    rank  country     density   densityMi  population   area
# 0     1    Macau  21946.4667  56841.3487     658.394     30
# 1     2   Monaco  19755.5000  51166.7450      39.511      2
# 2    28  Burundi    440.3044   1140.3884   12255.433  27834
# 3     1    Macau  21946.4667  56841.3487     658.394     30
# 4     2   Monaco  19755.5000  51166.7450      39.511      2

# %% [markdown]
# # .cut() va qcut yordamida guruhlash

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 3-MODUL. MA’LUMOTLARGA ISHLOV BERISH
#
# ### 3.2 Ma'lumotlarni tozalash va tayyorlash
#
# ## Guruhlash
# Guruhlashning vazifasi ma'lumotlarni tahlil qilish uchun biror ustun qiymatlarini berilgan oraliqlarga (guruhlarga) tushurib olish.
#
# Misol uchun, sizda foydalanuvchilar haqida ma'lumotlar jamlangan va u yerda har bir foydalanuvchining yoshi ham ko'rsatilgan. Siz foydalanuvchilarni qaysi yosh oralig'ida ekanini (qaysi guruhga tegishli ekanini) ko'rmoqchisiz:
#
# ![](https://www.researchgate.net/profile/Gemma-Burgess-5/publication/299603937/figure/fig1/AS:347169551863808@1459783079654/The-age-ranges-of-survey-respondents.png)
#
# Yuqoridagi kabi natijani olish uchun biz foydalanauvchilarni yosihga qarab ma'lum oraliqqa joylashimiz kerak, `pandas` bu jarayonni bir muncha osonlashtiradi.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv', usecols=['country','pop2021','area'], index_col='country')
df.head()
# Out:
#            pop2021   area
# country
# Macau      658.394     30
# Monaco      39.511      2
# Burundi  12255.433  27834
# Macau      658.394     30
# Monaco      39.511      2

# %%
df.drop_duplicates(inplace=True)

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                   pop2021     area
# country
# Afghanistan     39835.428   652230
# Albania          2872.933    28748
# Algeria         44616.624  2381741
# American Samoa     55.100      199
# Andorra            77.355      468

# %%
df.loc['Uzbekistan']
# Out:
# pop2021     33935.763
# area       447400.000
# Name: Uzbekistan, dtype: float64

# %%
df.loc['China']
# Out:
# pop2021    1444216.107
# area       9706961.000
# Name: China, dtype: float64

# %% [markdown]
# Keling, quyidagi oraliqlarda nechtadan davlat borligini tahlil qilamiz:
# - 1 milliongacha (`0-1000`)
# - 1-10mln oraqlida (`1000-10000`)
# - 10-30mln oraliqda (`10000-30000`)
# - 30-50mln oraliqda (`30000-50000`)
# - 50-100mln (`50000-10000`)
# - 100-300mln (`100000-300000`)
# - 300mln-1.5mlrd (`300000-1500000`)
#
# Buning uchun quydagi bin (nuqtalarni) yaratib olamiz:

# %%
bins = [0, 1000, 10000, 30000, 50000, 100000, 300000, 1500000]

# %%
population = df.pop2021

# %%
population
# Out:
# country
# Afghanistan          39835.428
# Albania               2872.933
# Algeria              44616.624
# American Samoa          55.100
# Andorra                 77.355
#                        ...
# Wallis and Futuna       11.094
# Western Sahara         611.875
# Yemen                30490.640
# Zambia               18920.651
# Zimbabwe             15092.171
# Name: pop2021, Length: 232, dtype: float64

# %%
oraliq = pd.cut(population, bins)

# %%
df['oraliq']= oraliq

# %%
df.head()
# Out:
#                   pop2021     area          oraliq
# country
# Afghanistan     39835.428   652230  (30000, 50000]
# Albania          2872.933    28748   (1000, 10000]
# Algeria         44616.624  2381741  (30000, 50000]
# American Samoa     55.100      199       (0, 1000]
# Andorra            77.355      468       (0, 1000]

# %%
oraliq.value_counts()
# Out:
# (0, 1000]            72
# (1000, 10000]        68
# (10000, 30000]       44
# (30000, 50000]       19
# (50000, 100000]      15
# (100000, 300000]     11
# (300000, 1500000]     3
# Name: pop2021, dtype: int64

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df.price.describe() # describe() funksiyasi bizga statistikani chiqarin beradi
# Out:
# count       58.000000
# mean     15387.000000
# std      11320.259841
# min       5151.000000
# 25%       6808.500000
# 50%      11095.000000
# 75%      18120.500000
# max      45400.000000
# Name: price, dtype: float64

# %%
bins = [0, 10000, 20000, 50000]

# %%
range = pd.cut(df.price, bins)

# %%
range.value_counts()
# Out:
# (0, 10000]        28
# (10000, 20000]    17
# (20000, 50000]    13
# Name: price, dtype: int64

# %%
groups = ["arzon", "o'rta", "qimmat"]
ranges = pd.cut(df.price, bins, labels=groups)

# %%
ranges.value_counts()
# Out:
# arzon     28
# o'rta     17
# qimmat    13
# Name: price, dtype: int64

# %%
range = pd.qcut(df.price, 3)
range.value_counts()
# qcut maksimalni bir teng taqsimlab beradi
# Out:
# (5150.999, 7295.0]    20
# (7295.0, 16430.0]     19
# (16430.0, 45400.0]    19
# Name: price, dtype: int64

# %%
range = pd.qcut(df.horsepower, 3)
range.value_counts()
# Out:
# (47.999, 70.0]    24
# (111.0, 288.0]    20
# (70.0, 111.0]     17
# Name: horsepower, dtype: int64

# %% [markdown]
# # gruopby() yordamida guruhlash

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
# gropby() bo'yicha gurhlash bu juda kuchli funksiya hisoblanadi 
df.groupby('company').mean() # kompanya bo'yicha o'rtacha qiymat hisoblas
# Out:
#                wheel-base      length  horsepower  average-mileage  \
# company
# alfa-romero     90.566667  169.600000  125.333333        20.333333
# audi           101.200000  180.800000  109.250000        20.000000
# bmw            103.433333  185.033333  144.833333        19.000000
# chevrolet       92.466667  151.933333   62.666667        41.000000
# dodge           93.700000  157.300000   68.000000        31.000000
# honda           96.500000  167.200000   92.333333        26.333333
# isuzu           94.433333  160.833333   72.666667        33.333333
# jaguar         109.333333  196.966667  204.666667        14.333333
# mazda           95.900000  164.260000   75.400000        28.000000
# mercedes-benz  113.225000  197.275000  153.500000        18.000000
# mitsubishi      95.000000  164.850000   78.000000        29.500000
# nissan          95.680000  170.140000   82.800000        31.400000
# porsche         92.466667  171.166667  234.000000        17.000000
# ...

# %%
df.groupby('company').max()
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               wagon       105.8   192.7         ohc             four
# bmw                sedan       110.0   197.0         ohc              six
# chevrolet          sedan        94.5   158.8         ohc            three
# dodge          hatchback        93.7   157.3         ohc             four
# honda              wagon        96.5   175.4         ohc             four
# isuzu              sedan        94.5   170.7         ohc             four
# jaguar             sedan       113.0   199.6        ohcv           twelve
# mazda              sedan       104.9   175.0       rotor              two
# mercedes-benz      wagon       120.9   208.1        ohcv             five
# mitsubishi         sedan        96.3   172.4         ohc             four
# ...

# %%
df.groupby('company').price.max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
type(df.groupby('company').price.max())
# Out:
# pandas.core.series.Series

# %%
df.groupby(['company','body-style']).price.max()
# Out:
# company        body-style
# alfa-romero    convertible    16500.0
#                hatchback      16500.0
# audi           sedan          17450.0
#                wagon          18920.0
# bmw            sedan          41315.0
# chevrolet      hatchback       6295.0
#                sedan           6575.0
# dodge          hatchback       6377.0
# honda          sedan          12945.0
#                wagon           7295.0
# isuzu          sedan           6785.0
# jaguar         sedan          36000.0
# mazda          hatchback      11845.0
#                sedan          18344.0
# mercedes-benz  hardtop        45400.0
#                sedan          40960.0
#                wagon          28248.0
# mitsubishi     hatchback       6189.0
#                sedan           8189.0
# nissan         sedan          13499.0
#                wagon           7349.0
# porsche        convertible    37028.0
#                hardtop        34028.0
#                hatchback          NaN
# ...

# %%
df.groupby('company').agg([max,min,np.mean]) # agg funksiyasi bir nechta funksiyalarni ishlatib guruhlab beradi
# Out:
#               wheel-base                    length                     \
#                      max    min        mean    max    min        mean
# company
# alfa-romero         94.5   88.6   90.566667  171.2  168.8  169.600000
# audi               105.8   99.4  101.200000  192.7  176.6  180.800000
# bmw                110.0  101.2  103.433333  197.0  176.8  185.033333
# chevrolet           94.5   88.4   92.466667  158.8  141.1  151.933333
# dodge               93.7   93.7   93.700000  157.3  157.3  157.300000
# honda               96.5   96.5   96.500000  175.4  157.1  167.200000
# isuzu               94.5   94.3   94.433333  170.7  155.9  160.833333
# jaguar             113.0  102.0  109.333333  199.6  191.7  196.966667
# mazda              104.9   93.1   95.900000  175.0  159.1  164.260000
# mercedes-benz      120.9  110.0  113.225000  208.1  190.9  197.275000
# mitsubishi          96.3   93.7   95.000000  172.4  157.3  164.850000
# ...

# %%
df.groupby('company').agg([max,min,np.mean, lambda x: max(x)])
# Out:
#               wheel-base                               length         \
#                      max    min        mean <lambda_0>    max    min
# company
# alfa-romero         94.5   88.6   90.566667       94.5  171.2  168.8
# audi               105.8   99.4  101.200000      105.8  192.7  176.6
# bmw                110.0  101.2  103.433333      110.0  197.0  176.8
# chevrolet           94.5   88.4   92.466667       94.5  158.8  141.1
# dodge               93.7   93.7   93.700000       93.7  157.3  157.3
# honda               96.5   96.5   96.500000       96.5  175.4  157.1
# isuzu               94.5   94.3   94.433333       94.5  170.7  155.9
# jaguar             113.0  102.0  109.333333      113.0  199.6  191.7
# mazda              104.9   93.1   95.900000      104.9  175.0  159.1
# mercedes-benz      120.9  110.0  113.225000      120.9  208.1  190.9
# mitsubishi          96.3   93.7   95.000000       96.3  172.4  157.3
# ...

# %% [markdown]
# # g'ayritabiiy qiymatlar bilan ishlash

# %%
df = pd.read_csv('MOCK_USER_DATA.csv')

# %%
df.describe()    #bu jadval haqida ma'lumot beradi
# Out:
#                id          age
# count  100.000000   100.000000
# mean    50.500000   145.660000
# std     29.011492   565.631411
# min      1.000000   -85.000000
# 25%     25.750000    22.750000
# 50%     50.500000    53.500000
# 75%     75.250000    84.250000
# max    100.000000  4444.000000

# %%
df[df.age<0]
# Out:
#     id first_name  last_name                           email       gender  age
# 10  11     Elijah      Heine                eheinea@imdb.com     Bigender  -85
# 18  19      Luisa  Bradborne            lbradbornei@fema.gov       Female  -75
# 20  21      Levin     Worner                lwornerk@ihg.com  Genderqueer  -43
# 32  33   Ebenezer    Greeves           egreevesw@myspace.com         Male  -26
# 37  38       Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer  -42
# 89  90  Zachariah      Meins            zmeins2h@weather.com         Male  -69

# %%
df.age = df['age'].apply(abs)

# %%
df[df.age<0]
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, gender, age]
# Index: []

# %%
idx = df[df['age']>123].index

# %%
df.drop(index=idx, inplace=True)

# %%
df.describe() # endi bu haqiqatga to'g'ri bo'ldi
# Out:
#               id         age
# count  93.000000   93.000000
# mean   50.182796   52.612903
# std    29.001854   29.978265
# min     1.000000    1.000000
# 25%    25.000000   29.000000
# 50%    51.000000   52.000000
# 75%    75.000000   77.000000
# max    99.000000  100.000000

# %% [markdown]
# # jadvallarni tasodifiy qiymatlarni olish

# %%
df
# Out:
#     id first_name   last_name                           email       gender  \
# 0    1    Dorothy     Verryan               dverryan0@who.int   Non-binary
# 1    2    Pietrek     Scanlin          pscanlin1@yolasite.com         Male
# 3    4       Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid
# 4    5   Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female
# 5    6      Glynn      Ebbing          gebbing5@rakuten.co.jp  Genderfluid
# ..  ..        ...         ...                             ...          ...
# 94  95      Byron  Whittleton   bwhittleton2m@theatlantic.com   Non-binary
# 95  96       Baxy       Marcu        bmarcu2n@list-manage.com      Agender
# 96  97     Kattie     Claxson          kclaxson2o@booking.com       Female
# 97  98       Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender
# 98  99  Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid
#
#     age
# 0     1
# 1    91
# 3     6
# 4    48
# 5    77
# ..  ...
# ...

# %%
randlist =np.random.permutation(93)

# %%
randlist
# Out:
# array([82, 92, 27, 80, 34,  1, 60,  7, 83, 48, 68, 39, 24, 63,  3, 64, 35,
#        18, 47,  8, 57, 54, 21, 70, 26, 17, 10, 13, 72,  0,  5, 79, 73, 74,
#        62, 31, 91, 45, 49, 37, 19, 85, 76, 56, 87, 89, 88, 23, 33, 50, 53,
#        25, 15, 61, 59,  6, 71, 46, 43, 32, 51, 29, 28, 58, 41, 20, 16, 69,
#        67,  9, 77, 90, 55, 66, 42, 36, 84, 44, 11,  2, 38, 22,  4, 52, 40,
#        78, 75, 12, 30, 86, 81, 65, 14])

# %%
df = df.take(randlist) # bu index o'rniga tasodifiy qiymatlarni qoyadi

# %%
df.drop(columns='id',inplace =True)

# %%
df.head()
# Out:
#    first_name last_name                     email       gender  age
# 88     Ebonee  Eastbury    eeastbury2g@smh.com.au  Genderqueer   16
# 98  Desdemona   Jurasek  djurasek2q@aboutads.info  Genderfluid   46
# 28      Biron  Acklands    backlandss@comsenz.com         Male   13
# 86      Peder    Murrie   pmurrie2e@bloglovin.com         Male   69
# 35        Axe   Arundel       aarundelz@yahoo.com       Female   14

# %%
df.sample(10) # bu method bizga tasodifiy 10 qiymatni qaytaradi
# Out:
#    first_name    last_name                           email       gender  age
# 9       David     Meredyth      dmeredyth9@telegraph.co.uk       Female   68
# 40   Katheryn     Ashleigh          kashleigh14@devhub.com      Agender   36
# 71   Eleanora      Kamenar         ekamenar1z@examiner.com         Male   47
# 35        Axe      Arundel             aarundelz@yahoo.com       Female   14
# 97       Clem      Fullerd  cfullerd2p@creativecommons.org     Bigender   55
# 16      Byram  Martynikhin       bmartynikhing@jiathis.com         Male   40
# 7         Nye    Anthiftle        nanthiftle7@examiner.com      Agender   99
# 69      Ambur       Aickin             aaickin1x@about.com         Male   60
# 72      Liane      Cackett            lcackett20@jigsy.com  Genderqueer   40
# 52    Demeter      Widdall           dwiddall1g@flavors.me     Bigender   90

# %% [markdown]
# # kaggle bilan tanishuv

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('database.csv')

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
import datetime as dt

# %%
hozir = dt.datetime.now()

# %%
hozir
# Out:
# datetime.datetime(2022, 7, 10, 17, 13, 13, 106550)

# %%
print(hozir)
# Out:
# 2022-07-10 17:13:13.106550

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
df.at[0,'Date'] # bu ustundagi bitta qiymatga murojat qilish
# Out:
# '01/02/1965'

# %%
pd.to_datetime(df['Date'], format='%m/%d/%Y')
# Out:
# 0       1965-01-02
# 1       1965-01-04
# 2       1965-01-05
# 3       1965-01-08
# 4       1965-01-09
#            ...
# 23407   2016-12-28
# 23408   2016-12-28
# 23409   2016-12-28
# 23410   2016-12-29
# 23411   2016-12-30
# Name: Date, Length: 23409, dtype: datetime64[ns]

# %%
df['Date'].str.len() # bu har bir qatordagi qatorlar uzunligini qaytaradi
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 23407    10
# 23408    10
# 23409    10
# 23410    10
# 23411    10
# Name: Date, Length: 23412, dtype: int64

# %%
df['Date'].str.len()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23407    False
# 23408    False
# 23409    False
# 23410    False
# 23411    False
# Name: Date, Length: 23412, dtype: bool

# %%
df['Date'].str.len().value_counts()
# Out:
# 10    23409
# 24        3
# Name: Date, dtype: int64

# %%
df1 = df[df['Date'].str.len()==24]

# %%
df1.index
# Out:
# Int64Index([3378, 7512, 20650], dtype='int64')

# %%
df.drop(index=[3378, 7512, 20650], inplace=True)

# %%
df[df['Date'].str.len()==24]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Latitude, Longitude, Type, Depth, Depth Error, Depth Seismic Stations, Magnitude, Magnitude Type, Magnitude Error, Magnitude Seismic Stations, Azimuthal Gap, Horizontal Distance, Horizontal Error, Root Mean Square, ID, Source, Location Source, Magnitude Source, Status]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Date']
# Out:
# 0        01/02/1965
# 1        01/04/1965
# 2        01/05/1965
# 3        01/08/1965
# 4        01/09/1965
#             ...
# 23407    12/28/2016
# 23408    12/28/2016
# 23409    12/28/2016
# 23410    12/29/2016
# 23411    12/30/2016
# Name: Date, Length: 23409, dtype: object

# %%
df['detatime']=pd.to_datetime(df['Date'], format='%m/%d/%Y')

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
# 3                     NaN        5.8             MW  ...            NaN
# 4                     NaN        5.8             MW  ...            NaN
#
# ...

# %%
df.at[0,'detatime'].weekday() # bu hafta kunlari ajratib ko'rsatish
# Out:
# 5

# %%
month = df['detatime'].dt.month # bu detatime dagi oylarni ajratib berish ko'rasatadi

# %%
month.value_counts() # bu qaysi oyda  ko'p zilzila bo'lgani ko'rish
# Out:
# 3     2113
# 8     2014
# 12    2001
# 11    1987
# 9     1985
# 4     1970
# 5     1964
# 10    1952
# 1     1891
# 7     1880
# 2     1828
# 6     1824
# Name: detatime, dtype: int64

# %%
df['vaqt']=pd.to_datetime(df['Time'], format='%H:%M:%S')

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Horizontal Distance  \
# 0                     NaN        6.0             MW  ...                  NaN
# 1                     NaN        5.8             MW  ...                  NaN
# 2                     NaN        6.2             MW  ...                  NaN
# 3                     NaN        5.8             MW  ...                  NaN
# 4                     NaN        5.8             MW  ...                  NaN
#
# ...

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...
