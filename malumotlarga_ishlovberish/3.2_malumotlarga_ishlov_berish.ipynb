# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # irarxix indekslash
# ## muti indexlash

# %%
data= pd.Series(np.random.randn(9), index = ['a','a','a','b','b','c','c','d','d'])

# %%
data.index # indexni chiqarish
# Out:
# Index(['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], dtype='object')

# %%
data1 = pd.Series(np.random.randn(9), index = [['a','a','a','b','b','c','c','d','d'],[1,2,3,3,2,1,2,2,3]])
# irarxik indexni chop qiladi

# %%
data
# Out:
# a   -0.453305
# a   -0.376874
# a   -0.123695
# b    0.763489
# b    1.090246
# c   -0.667371
# c    0.305276
# d    0.064473
# d   -0.329523
# dtype: float64

# %%
data1
# Out:
# a  1   -1.220298
#    2    0.457142
#    3    0.083710
# b  3    0.855420
#    2   -0.374742
# c  1   -0.674836
#    2    0.015980
# d  2   -1.124247
#    3    2.431716
# dtype: float64

# %%
data1.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 3),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
data2 = data1.unstack() # Pd dagi Seriesni Dataframe korinishda o'tqizadi 
data2
# Out:
#           1         2         3
# a -1.220298  0.457142  0.083710
# b       NaN -0.374742  0.855420
# c -0.674836  0.015980       NaN
# d       NaN -1.124247  2.431716

# %%
data2.stack() # dataframeni Series ko'rinishda o'tqizadi
# Out:
# a  1   -1.220298
#    2    0.457142
#    3    0.083710
# b  2   -0.374742
#    3    0.855420
# c  1   -0.674836
#    2    0.015980
# d  2   -1.124247
#    3    2.431716
# dtype: float64

# %%
data1['a'] # subsetlari bilan kesib olib beradi
# Out:
# 1   -1.220298
# 2    0.457142
# 3    0.083710
# dtype: float64

# %%
data1.loc[:,2] # barcha 2 indexli ma'lumotlarimizni kesib oladi
# Out:
# a    0.457142
# b   -0.374742
# c    0.015980
# d   -1.124247
# dtype: float64

# %%
data1.loc[['b','c']] # barcha b va c dagi ma'lumotlarimizni chop qilib oladi
# Out:
# b  3    0.855420
#    2   -0.374742
# c  1   -0.674836
#    2    0.015980
# dtype: float64

# %% [markdown]
# # .stack() va unstack() Dataframe ma'lumotlar

# %%
data2 = data1.unstack() # bu  Series ma'lumot turidan Dataframe malumotlarga turiga o'tqazadi

# %%
data2.stack() # bu Dataframedan Seriesga o'tqizadi
# Out:
# a  1   -1.220298
#    2    0.457142
#    3    0.083710
# b  2   -0.374742
#    3    0.855420
# c  1   -0.674836
#    2    0.015980
# d  2   -1.124247
#    3    2.431716
# dtype: float64

# %% [markdown]
# # Dunyo shaharlarining hava suv sifati ma'lumotlari

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Unpacking objects: 100% (60/60), done.

# %%
df = pd.read_csv('Practicum_Datasets/world_cities_air_water_quality.csv')

# %%
df.head(
    
)
# Out:
#                City                 "Region"                    "Country"  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#     "AirQuality"   "WaterPollution"
# 0      46.816038          49.504950
# 1      66.129032          49.107143
# 2      60.514019          43.000000
# 3      62.364130          28.612717
# 4      36.621622          61.299435

# %%
df.describe()
# Out:
#         "AirQuality"   "WaterPollution"
# count    3963.000000        3963.000000
# mean       62.253452          44.635372
# std        30.944753          25.663910
# min         0.000000           0.000000
# 25%        37.686567          25.000000
# 50%        69.444444          50.000000
# 75%        87.500000          57.719393
# max       100.000000         100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
df.head(
    
)
# Out:
#                City                 "Region"                    "Country"  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#     "AirQuality"   "WaterPollution"
# 0      46.816038          49.504950
# 1      66.129032          49.107143
# 2      60.514019          43.000000
# 3      62.364130          28.612717
# 4      36.621622          61.299435

# %%
columns = ['City','Region','Country','AirQuality','WaterPollution']
df.columns = columns

# %%
df.head()
# Out:
#                City                   Region                      Country  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df['Region']=df['Region'].map(lambda x: x.replace('"'," "))

# %%
df['Country']=df['Country'].map(lambda x: x.replace('"'," "))

# %%
df.head(
    
)
# Out:
#                City                   Region                      Country  \
# 0     New York City                New York     United States of America
# 1  Washington, D.C.    District of Columbia     United States of America
# 2     San Francisco              California     United States of America
# 3            Berlin                                              Germany
# 4       Los Angeles              California     United States of America
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df.to_csv('update.csv', index=False)

# %%
df1  =pd.read_csv('update.csv')

# %%
df1.head()
# Out:
#                City                   Region                      Country  \
# 0     New York City                New York     United States of America
# 1  Washington, D.C.    District of Columbia     United States of America
# 2     San Francisco              California     United States of America
# 3            Berlin                                              Germany
# 4       Los Angeles              California     United States of America
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df.head(
    
)
# Out:
#                City                   Region                      Country  \
# 0     New York City                New York     United States of America
# 1  Washington, D.C.    District of Columbia     United States of America
# 2     San Francisco              California     United States of America
# 3            Berlin                                              Germany
# 4       Los Angeles              California     United States of America
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df['Country']=df['Country'].map(lambda x: x.strip()) # strip bu bo'sh joyni olib tashlaydi

# %%
df['Country'][3]
# Out:
# 'Germany'

# %%
df[df['Country']=='Uzbekistan']
# Out:
#         City Region     Country  AirQuality  WaterPollution
# 21  Tashkent         Uzbekistan   56.451613       49.166667

# %%
df1 = pd.pivot_table(df, index=['Country','City']) # pivot teble indexlarni irarxik indexga o'tqizadi

# %%
df1.head()
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3963, step=1)

# %%
df1.index
# Out:
# MultiIndex([('Afghanistan',        'Andkhoy'),
#             ('Afghanistan',          'Farah'),
#             ('Afghanistan',          'Herat'),
#             ('Afghanistan',          'Kabul'),
#             ('Afghanistan',       'Kandahar'),
#             ('Afghanistan', 'Mazar-i-Sharif'),
#             (    'Albania',         'Ballsh'),
#             (    'Albania',         'Burrel'),
#             (    'Albania',         'Durres'),
#             (    'Albania',        'Elbasan'),
#             ...
#             (      'Yemen',          'Sanaa'),
#             (      'Yemen',         'Ta'izz'),
#             (     'Zambia',       'Chingola'),
#             (     'Zambia',          'Kitwe'),
#             (     'Zambia',         'Lusaka'),
#             (     'Zambia',          'Mansa'),
#             (   'Zimbabwe',        'Bindura'),
#             (   'Zimbabwe',       'Bulawayo'),
#             (   'Zimbabwe',         'Harare'),
#             (   'Zimbabwe',       'Masvingo')],
# ...

# %%
df1.loc[['Uzbekistan','Germany']]
# Out:
#                           AirQuality  WaterPollution
# Country    City
# Uzbekistan Tashkent        56.451613       49.166667
# Germany    Aachen          70.454545       17.857143
#            Aalen           87.500000       50.000000
#            Abensberg      100.000000       50.000000
#            Amberg         100.000000       50.000000
# ...                              ...             ...
#            Wilhelmshaven  100.000000       50.000000
#            Wolfsburg       96.875000        0.000000
#            Worms           60.000000      100.000000
#            Wuppertal       90.000000        0.000000
#            Zwickau         75.000000       50.000000
#
# [125 rows x 2 columns]

# %% [markdown]
# # ustunlarni irarxik ko'rinishda o'tqazish

# %%
df2 = df1.copy()

# %%
df2.head()
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000

# %%
df2['AirPolution'] = 100-df2['AirQuality']

# %%
df2
# Out:
#                       AirQuality  WaterPollution  AirPolution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000    50.000000
#             Farah     100.000000        0.000000     0.000000
#             Herat      43.750000       31.250000    56.250000
#             Kabul      18.421053       81.060606    81.578947
#             Kandahar    0.000000       75.000000   100.000000
# ...                          ...             ...          ...
# Zambia      Mansa      75.000000       25.000000    25.000000
# Zimbabwe    Bindura    50.000000       75.000000    50.000000
#             Bulawayo   67.857143       71.428571    32.142857
#             Harare     38.461538       87.500000    61.538462
#             Masvingo   25.000000       62.500000    75.000000
#
# [3895 rows x 3 columns]

# %%
df2['Water'] = 100-df2['WaterPollution']

# %%
df2.head()
# Out:
#                       AirQuality  WaterPollution  AirPolution       Water
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000    50.000000   50.000000
#             Farah     100.000000        0.000000     0.000000  100.000000
#             Herat      43.750000       31.250000    56.250000   68.750000
#             Kabul      18.421053       81.060606    81.578947   18.939394
#             Kandahar    0.000000       75.000000   100.000000   25.000000

# %%
df3 = pd.DataFrame(df2.values, index = df2.index, columns=[['AIR','AIR','WATH','WATH'],['AirQuality','AirPolution','WaterPollution','Water']])

# %%
df3 # biz columnslarni irarxik ko'rinishda o'tqazish
# Out:
#                              AIR                       WATH
#                       AirQuality AirPolution WaterPollution       Water
# Country     City
# Afghanistan Andkhoy    50.000000   50.000000      50.000000   50.000000
#             Farah     100.000000    0.000000       0.000000  100.000000
#             Herat      43.750000   31.250000      56.250000   68.750000
#             Kabul      18.421053   81.060606      81.578947   18.939394
#             Kandahar    0.000000   75.000000     100.000000   25.000000
# ...                          ...         ...            ...         ...
# Zambia      Mansa      75.000000   25.000000      25.000000   75.000000
# Zimbabwe    Bindura    50.000000   75.000000      50.000000   25.000000
#             Bulawayo   67.857143   71.428571      32.142857   28.571429
#             Harare     38.461538   87.500000      61.538462   12.500000
#             Masvingo   25.000000   62.500000      75.000000   37.500000
#
# [3895 rows x 4 columns]

# %%
df3['AIR'] # bunda bizga ma'lumotlarni tushinarli ko'rinishga olib keladi
# Out:
#                       AirQuality  AirPolution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000
#             Farah     100.000000     0.000000
#             Herat      43.750000    31.250000
#             Kabul      18.421053    81.060606
#             Kandahar    0.000000    75.000000
# ...                          ...          ...
# Zambia      Mansa      75.000000    25.000000
# Zimbabwe    Bindura    50.000000    75.000000
#             Bulawayo   67.857143    71.428571
#             Harare     38.461538    87.500000
#             Masvingo   25.000000    62.500000
#
# [3895 rows x 2 columns]

# %%
df3.columns.names = ['object','info']

# %%
df3
# Out:
# object                       AIR                       WATH
# info                  AirQuality AirPolution WaterPollution       Water
# Country     City
# Afghanistan Andkhoy    50.000000   50.000000      50.000000   50.000000
#             Farah     100.000000    0.000000       0.000000  100.000000
#             Herat      43.750000   31.250000      56.250000   68.750000
#             Kabul      18.421053   81.060606      81.578947   18.939394
#             Kandahar    0.000000   75.000000     100.000000   25.000000
# ...                          ...         ...            ...         ...
# Zambia      Mansa      75.000000   25.000000      25.000000   75.000000
# Zimbabwe    Bindura    50.000000   75.000000      50.000000   25.000000
#             Bulawayo   67.857143   71.428571      32.142857   28.571429
#             Harare     38.461538   87.500000      61.538462   12.500000
#             Masvingo   25.000000   62.500000      75.000000   37.500000
#
# [3895 rows x 4 columns]

# %%
df3.index.names  # indexdagi nomlarini ko'rish
# Out:
# FrozenList(['Country', 'City'])

# %%
df3
# Out:
# object                       AIR                       WATH
# info                  AirQuality AirPolution WaterPollution       Water
# Country     City
# Afghanistan Andkhoy    50.000000   50.000000      50.000000   50.000000
#             Farah     100.000000    0.000000       0.000000  100.000000
#             Herat      43.750000   31.250000      56.250000   68.750000
#             Kabul      18.421053   81.060606      81.578947   18.939394
#             Kandahar    0.000000   75.000000     100.000000   25.000000
# ...                          ...         ...            ...         ...
# Zambia      Mansa      75.000000   25.000000      25.000000   75.000000
# Zimbabwe    Bindura    50.000000   75.000000      50.000000   25.000000
#             Bulawayo   67.857143   71.428571      32.142857   28.571429
#             Harare     38.461538   87.500000      61.538462   12.500000
#             Masvingo   25.000000   62.500000      75.000000   37.500000
#
# [3895 rows x 4 columns]

# %% [markdown]
# # Qayta tartiblash
# ##swaplevel() sort_index() haqida

# %%
df3.head()
# Out:
# object                       AIR                       WATH
# info                  AirQuality AirPolution WaterPollution       Water
# Country     City
# Afghanistan Andkhoy    50.000000   50.000000      50.000000   50.000000
#             Farah     100.000000    0.000000       0.000000  100.000000
#             Herat      43.750000   31.250000      56.250000   68.750000
#             Kabul      18.421053   81.060606      81.578947   18.939394
#             Kandahar    0.000000   75.000000     100.000000   25.000000

# %%
df3.swaplevel('Country','City') # ierarxik indexlarni o'rnini almashtiradi
# Out:
# object                       AIR                       WATH
# info                  AirQuality AirPolution WaterPollution       Water
# City     Country
# Andkhoy  Afghanistan   50.000000   50.000000      50.000000   50.000000
# Farah    Afghanistan  100.000000    0.000000       0.000000  100.000000
# Herat    Afghanistan   43.750000   31.250000      56.250000   68.750000
# Kabul    Afghanistan   18.421053   81.060606      81.578947   18.939394
# Kandahar Afghanistan    0.000000   75.000000     100.000000   25.000000
# ...                          ...         ...            ...         ...
# Mansa    Zambia        75.000000   25.000000      25.000000   75.000000
# Bindura  Zimbabwe      50.000000   75.000000      50.000000   25.000000
# Bulawayo Zimbabwe      67.857143   71.428571      32.142857   28.571429
# Harare   Zimbabwe      38.461538   87.500000      61.538462   12.500000
# Masvingo Zimbabwe      25.000000   62.500000      75.000000   37.500000
#
# [3895 rows x 4 columns]

# %%
df3.sort_index(level=0,ascending=False) # bu ierarxik ma'lumotlarimizni teskari tartibda tartiblash
# Out:
# object                       AIR                       WATH
# info                  AirQuality AirPolution WaterPollution       Water
# Country     City
# Zimbabwe    Masvingo   25.000000   62.500000      75.000000   37.500000
#             Harare     38.461538   87.500000      61.538462   12.500000
#             Bulawayo   67.857143   71.428571      32.142857   28.571429
#             Bindura    50.000000   75.000000      50.000000   25.000000
# Zambia      Mansa      75.000000   25.000000      25.000000   75.000000
# ...                          ...         ...            ...         ...
# Afghanistan Kandahar    0.000000   75.000000     100.000000   25.000000
#             Kabul      18.421053   81.060606      81.578947   18.939394
#             Herat      43.750000   31.250000      56.250000   68.750000
#             Farah     100.000000    0.000000       0.000000  100.000000
#             Andkhoy    50.000000   50.000000      50.000000   50.000000
#
# [3895 rows x 4 columns]

# %% [markdown]
# # malumotlar to'plami (sql uslubu)
# ##merge(), join()

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Unpacking objects: 100% (60/60), done.

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Practicum_Datasets/IMDb/IMDb_movies.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# ...

# %%
df2 = pd.read_csv('Practicum_Datasets/IMDb/IMDb_ratings.csv')

# %%
df2.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes
# 0     tt0000009                    5.9          154
# 1     tt0000574                    6.1          589
# 2     tt0001892                    5.8          188
# 3     tt0002101                    5.2          446
# 4     tt0002130                    7.0         2237

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   weighted_average_vote  85855 non-null  float64
#  2   total_votes            85855 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.0+ MB

# %%
pd.Series

# %%
movies_reating =pd.merge(df1,df2) # merge() funksiyasi jadvallarni birlashtirish uchun ishlatiladi

# %%
movies_reating.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'budget',
#        'weighted_average_vote', 'total_votes'],
#       dtype='object')

# %%
df1.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes
# 0     tt0000009                    5.9          154
# 1     tt0000574                    6.1          589
# 2     tt0001892                    5.8          188
# 3     tt0002101                    5.2          446
# 4     tt0002130                    7.0         2237

# %%
kesib_olish = movies_reating[ ['title','year', 'weighted_average_vote']]

# %%
kesib_olish
# Out:
#                                 title  year  weighted_average_vote
# 0                          Miss Jerry  1894                    5.9
# 1         The Story of the Kelly Gang  1906                    6.1
# 2                      Den sorte drøm  1911                    5.8
# 3                           Cleopatra  1912                    5.2
# 4                           L'Inferno  1911                    7.0
# ...                               ...   ...                    ...
# 85850                         Le lion  2020                    5.3
# 85851  De Beentjes van Sint-Hildegard  2020                    7.7
# 85852       Padmavyuhathile Abhimanyu  2019                    7.9
# 85853               Sokagin Çocuklari  2019                    6.4
# 85854      La vida sense la Sara Amat  2019                    6.7
#
# [85855 rows x 3 columns]

# %%
A = pd.DataFrame({'Transport': ['poezd', 'avtomabil', 'kema'], 
                  'Tezligi':['70', '180', '45']})
                  
A
# Out:
#    Transport Tezligi
# 0      poezd      70
# 1  avtomabil     180
# 2       kema      45

# %%
B = pd.DataFrame({'Transport': ['poezd', 'avtomabil', 'tramvay'], 
                  'Narxi':['98000', '10000', '65000']})
                  
B
# Out:
#    Transport  Narxi
# 0      poezd  98000
# 1  avtomabil  10000
# 2    tramvay  65000

# %%
obj = pd.merge(A,B, how='inner') # inner yozmasak ham innerda bo'ladi yani jadvalda faqat ikkila ustunda borlarini oladi

# %%
obj
# Out:
#    Transport Tezligi  Narxi
# 0      poezd      70  98000
# 1  avtomabil     180  10000

# %%
merget_aothor  =pd.merge(A,B,how='outer') # outer esa ikkasidagilarni hammasini oladi

# %%
merget_aothor
# Out:
#    Transport Tezligi  Narxi
# 0      poezd      70  98000
# 1  avtomabil     180  10000
# 2       kema      45    NaN
# 3    tramvay     NaN  65000

# %%
merget_aothor  =pd.merge(A,B,how='left') # umumiy bo'lmagan A dagi elemetnlarni oladi boshqasini olmaydi

# %%
merget_aothor
# Out:
#    Transport Tezligi  Narxi
# 0      poezd      70  98000
# 1  avtomabil     180  10000
# 2       kema      45    NaN

# %%
A = pd.DataFrame({'Transport_turi': ['poezd', 'avtomabil', 'kema'], 
                  'Tezligi':['70', '180', '45']})
                  
A
# Out:
#   Transport_turi Tezligi
# 0          poezd      70
# 1      avtomabil     180
# 2           kema      45

# %%
B
# Out:
#    Transport  Narxi
# 0      poezd  98000
# 1  avtomabil  10000
# 2    tramvay  65000

# %%
merg  = pd.merge(A, B, left_on='Transport_turi', right_on='Transport')

# %%
merg
# Out:
#   Transport_turi Tezligi  Transport  Narxi
# 0          poezd      70      poezd  98000
# 1      avtomabil     180  avtomabil  10000

# %%
A = A.set_index('Transport_turi')

# %%
A
# Out:
#                Tezligi
# Transport_turi
# poezd               70
# avtomabil          180
# kema                45

# %%
B
# Out:
#    Transport  Narxi
# 0      poezd  98000
# 1  avtomabil  10000
# 2    tramvay  65000

# %%
merges = pd.merge(A,B, left_index=True, right_on='Transport')

# %%
merges
# Out:
#   Tezligi  Transport  Narxi
# 0      70      poezd  98000
# 1     180  avtomabil  10000

# %%
B = B.set_index('Transport')

# %%
B
# Out:
#            Narxi
# Transport
# poezd      98000
# avtomabil  10000
# tramvay    65000

# %%
obj = pd.merge(A,B, left_index=True,right_index=True)

# %%
obj
# Out:
#           Tezligi  Narxi
# poezd          70  98000
# avtomabil     180  10000

# %% [markdown]
# # malumotlarni ulash .concat() (concatination)

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
bank  = pd.read_csv('Practicum_Datasets/bank.csv',delimiter=";") # delimiter bu nuqta vergul olib tashlaydi

# %%
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank1, bank2 = bank[:2521], bank[2521:]

# %%
bank1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
pd.concat([bank1,bank2]) # concat() 2 ts datasetni ulash imkonyatini beradi
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# agar biz 3 ta bo'lakda bo'ladigan bo'lak 
bank1, bank2, bank3 = bank[:1000],bank[1000:2500], bank[2500:]

# %%
bank1
# Out:
#      age          job  marital  education default  balance housing loan  \
# 0     30   unemployed  married    primary      no     1787      no   no
# 1     33     services  married  secondary      no     4789     yes  yes
# 2     35   management   single   tertiary      no     1350     yes   no
# 3     30   management  married   tertiary      no     1476     yes  yes
# 4     59  blue-collar  married  secondary      no        0     yes   no
# ..   ...          ...      ...        ...     ...      ...     ...  ...
# 995   38  blue-collar  married  secondary      no     1370     yes   no
# 996   58   management  married  secondary      no       37      no   no
# 997   34   management   single   tertiary      no      673     yes  yes
# 998   40     services  married  secondary      no     -342     yes   no
# 999   20      student   single  secondary      no      291      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
pd.concat([bank1, bank2, bank3]) # 3 ta datasetni ulash
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.concat([bank1, bank2, bank3], axis=1) # columnlar orqali ulash
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0     30.0   unemployed  married    primary      no   1787.0      no   no
# 1     33.0     services  married  secondary      no   4789.0     yes  yes
# 2     35.0   management   single   tertiary      no   1350.0     yes   no
# 3     30.0   management  married   tertiary      no   1476.0     yes  yes
# 4     59.0  blue-collar  married  secondary      no      0.0     yes   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 4516   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4517   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4518   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4519   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 4520   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
#
#        contact   day  ... loan   contact   day  month  duration campaign  \
# ...

# %%
bank1 = bank1.set_index('age')

# %%
bank1
# Out:
#              job  marital  education default  balance housing loan    contact  \
# age
# 30    unemployed  married    primary      no     1787      no   no   cellular
# 33      services  married  secondary      no     4789     yes  yes   cellular
# 35    management   single   tertiary      no     1350     yes   no   cellular
# 30    management  married   tertiary      no     1476     yes  yes    unknown
# 59   blue-collar  married  secondary      no        0     yes   no    unknown
# ..           ...      ...        ...     ...      ...     ...  ...        ...
# 38   blue-collar  married  secondary      no     1370     yes   no   cellular
# 58    management  married  secondary      no       37      no   no   cellular
# 34    management   single   tertiary      no      673     yes  yes   cellular
# 40      services  married  secondary      no     -342     yes   no    unknown
# 20       student   single  secondary      no      291      no   no  telephone
#
# ...

# %%
bank2 = bank2.set_index('age')

# %%
bank2
# Out:
#                job  marital  education default  balance housing loan  \
# age
# 34      technician  married  secondary      no      209     yes  yes
# 31      technician   single   tertiary      no      438     yes   no
# 39          admin.   single  secondary      no     1242     yes   no
# 34    entrepreneur  married   tertiary      no      355     yes   no
# 24     blue-collar  married  secondary      no      204     yes  yes
# ..             ...      ...        ...     ...      ...     ...  ...
# 38   self-employed   single   tertiary      no      917     yes   no
# 46      management   single   tertiary      no      593     yes   no
# 42     blue-collar  married    primary      no      505     yes   no
# 34     blue-collar  married  secondary      no     2542     yes   no
# 37      management  married   tertiary      no     5355      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# age
# ...

# %%
pd.concat([bank1,bank2],axis=1 ) # bu xato beradi
# Out:
#                job  marital  education default  balance housing loan  \
# age
# 30      unemployed  married    primary      no     1787      no   no
# 33        services  married  secondary      no     4789     yes  yes
# 35      management   single   tertiary      no     1350     yes   no
# 30      management  married   tertiary      no     1476     yes  yes
# 59     blue-collar  married  secondary      no        0     yes   no
# ..             ...      ...        ...     ...      ...     ...  ...
# 38   self-employed   single   tertiary      no      917     yes   no
# 46      management   single   tertiary      no      593     yes   no
# 42     blue-collar  married    primary      no      505     yes   no
# 34     blue-collar  married  secondary      no     2542     yes   no
# 37      management  married   tertiary      no     5355      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# age
# ...

# %% [markdown]
# #pivet()

# %%
df = pd.read_csv('Practicum_Datasets/data_pivot.csv')

# %%
df.head()
# Out:
#                             date     item     value
# 0  1959-03-31 23:59:59.999999999  realgdp  2710.349
# 1  1959-03-31 23:59:59.999999999     infl     0.000
# 2  1959-03-31 23:59:59.999999999    unemp     5.800
# 3  1959-06-30 23:59:59.999999999  realgdp  2778.801
# 4  1959-06-30 23:59:59.999999999     infl     2.340

# %%
pivet_date = df.pivot('date','item','value')

# %%
pivet_date.head()
# Out:
# item                           infl   realgdp  unemp
# date
# 1959-03-31 23:59:59.999999999  0.00  2710.349    5.8
# 1959-06-30 23:59:59.999999999  2.34  2778.801    5.1
# 1959-09-30 23:59:59.999999999  2.74  2775.488    5.3
# 1959-12-31 23:59:59.999999999  0.27  2785.204    5.6
# 1960-03-31 23:59:59.999999999  2.31  2847.699    5.2

# %%
df['value2'] = np.random.randn(len(df))

# %%
df
# Out:
#                               date     item      value    value2
# 0    1959-03-31 23:59:59.999999999  realgdp   2710.349  1.489288
# 1    1959-03-31 23:59:59.999999999     infl      0.000  0.138634
# 2    1959-03-31 23:59:59.999999999    unemp      5.800  1.251371
# 3    1959-06-30 23:59:59.999999999  realgdp   2778.801 -1.861301
# 4    1959-06-30 23:59:59.999999999     infl      2.340 -0.348238
# ..                             ...      ...        ...       ...
# 604  2009-06-30 23:59:59.999999999     infl      3.370  0.612548
# 605  2009-06-30 23:59:59.999999999    unemp      9.200  0.561241
# 606  2009-09-30 23:59:59.999999999  realgdp  12990.341 -0.166654
# 607  2009-09-30 23:59:59.999999999     infl      3.560 -1.573266
# 608  2009-09-30 23:59:59.999999999    unemp      9.600  0.051945
#
# [609 rows x 4 columns]

# %%
pivetdata = df.pivot('date','item')

# %%
pivetdata
# Out:
#                               value                     value2            \
# item                           infl    realgdp unemp      infl   realgdp
# date
# 1959-03-31 23:59:59.999999999  0.00   2710.349   5.8  0.138634  1.489288
# 1959-06-30 23:59:59.999999999  2.34   2778.801   5.1 -0.348238 -1.861301
# 1959-09-30 23:59:59.999999999  2.74   2775.488   5.3  0.720412  0.687195
# 1959-12-31 23:59:59.999999999  0.27   2785.204   5.6  3.082592 -0.011528
# 1960-03-31 23:59:59.999999999  2.31   2847.699   5.2  0.170676  0.809661
# ...                             ...        ...   ...       ...       ...
# 2008-09-30 23:59:59.999999999 -3.16  13324.600   6.0 -0.246530 -1.167684
# 2008-12-31 23:59:59.999999999 -8.79  13141.920   6.9  0.004572 -0.018360
# 2009-03-31 23:59:59.999999999  0.94  12925.410   8.1 -0.460525 -0.621183
# 2009-06-30 23:59:59.999999999  3.37  12901.504   9.2  0.612548 -0.770474
# 2009-09-30 23:59:59.999999999  3.56  12990.341   9.6 -1.573266 -0.166654
#
#
# ...

# %%
pivetdata['value2'].head(10)
# Out:
# item                               infl   realgdp     unemp
# date
# 1959-03-31 23:59:59.999999999  0.138634  1.489288  1.251371
# 1959-06-30 23:59:59.999999999 -0.348238 -1.861301  1.253305
# 1959-09-30 23:59:59.999999999  0.720412  0.687195  1.664714
# 1959-12-31 23:59:59.999999999  3.082592 -0.011528  0.394625
# 1960-03-31 23:59:59.999999999  0.170676  0.809661  0.864129
# 1960-06-30 23:59:59.999999999 -1.624505  0.863506  1.199914
# 1960-09-30 23:59:59.999999999 -1.627713 -0.098725 -1.404557
# 1960-12-31 23:59:59.999999999  0.493178 -0.707469 -0.727058
# 1961-03-31 23:59:59.999999999  0.031931 -1.228673  0.424062
# 1961-06-30 23:59:59.999999999 -0.985591 -0.803924  1.583633
